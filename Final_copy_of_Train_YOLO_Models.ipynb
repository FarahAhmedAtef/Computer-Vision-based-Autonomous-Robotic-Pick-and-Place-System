# %% [markdown]
# <a href="https://colab.research.google.com/github/FarahAhmedAtef/Computer-Vision-based-Autonomous-Robotic-Pick-and-Place-System/blob/main/Final_copy_of_Train_YOLO_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Upload Dataset from Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/TestSweets/data.zip /content
# Out:
# Mounted at /content/gdrive

# %%
# !unzip -q /content/data.zip -d /content/custom_data

# %% [markdown]
# # &nbsp;Install Requirements (Ultralytics)

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 101.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# ## Run Training!

# %%
# !yolo detect train data=/content/custom_data/data.yaml model=yolo11n.pt epochs=50 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 5.35M/5.35M [00:00<00:00, 94.2MB/s]
# Ultralytics 8.3.137 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# #&nbsp;Test Model

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=/content/custom_data/test/images save=True save_txt=True
# Out:
# Ultralytics 8.3.137 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/12 /content/custom_data/test/images/IMG_2468_JPG.rf.67295981ae8a41d860ea921be47cfa03.jpg: 640x640 1 bounty, 1 lion, 1 mars, 1 milkyway, 1 snickers, 10.3ms
# image 2/12 /content/custom_data/test/images/IMG_2489_JPG.rf.30888cc692d21836612326a1caf3dce8.jpg: 640x640 1 bounty, 1 lion, 1 mars, 1 milkyway, 1 snickers, 9.1ms
# image 3/12 /content/custom_data/test/images/IMG_2490_JPG.rf.339bac00438cca22e3bffa729a59248a.jpg: 640x640 1 bounty, 1 lion, 2 marss, 1 milkyway, 1 snickers, 8.6ms
# image 4/12 /content/custom_data/test/images/IMG_2501_JPG.rf.7badaec13fe6574f5b4e032a0ce229e9.jpg: 640x640 1 lion, 1 mars, 1 milkyway, 3 snickerss, 8.7ms
# image 5/12 /content/custom_data/test/images/IMG_2514_JPG.rf.90cd87d72a6e06adea560a9fd263d4b1.jpg: 640x640 1 bounty, 1 lion, 1 mars, 1 milkyway, 1 snickers, 8.7ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/runs/detect/predict/*.jpg'):  # Updated path
    display(Image(filename=image_path, height=400))
    print('\n')

# %% [markdown]
# #&nbsp;Deploy Model

# %% [markdown]
# ## Download YOLO Model

# %%
# Create "my_model" folder to store model weights and training results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd /content/my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 10%)
#   adding: train/ (stored 0%)
#   adding: train/train_batch681.jpg (deflated 8%)
#   adding: train/confusion_matrix.png (deflated 29%)
#   adding: train/args.yaml (deflated 53%)
#   adding: train/results.png (deflated 8%)
#   adding: train/F1_curve.png (deflated 9%)
#   adding: train/val_batch0_pred.jpg (deflated 6%)
#   adding: train/confusion_matrix_normalized.png (deflated 25%)
#   adding: train/train_batch2.jpg (deflated 2%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/best.pt (deflated 10%)
#   adding: train/weights/last.pt (deflated 10%)
#   adding: train/train_batch0.jpg (deflated 2%)
#   adding: train/labels_correlogram.jpg (deflated 40%)
#   adding: train/R_curve.png (deflated 10%)
#   adding: train/train_batch1.jpg (deflated 2%)
#   adding: train/results.csv (deflated 62%)
#   adding: train/labels.jpg (deflated 29%)
#   adding: train/PR_curve.png (deflated 18%)
# ...

# %%
# This takes forever for some reason, you can also just download the model from the sidebar
from google.colab import files

files.download('/content/my_model.zip')
