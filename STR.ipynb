# %% [markdown]
# <a href="https://colab.research.google.com/github/FarahAhmedAtef/Computer-Vision-based-Autonomous-Robotic-Pick-and-Place-System/blob/main/STR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EasyOCR

# %%
# !pip install easyocr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 76.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 47.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 24.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Mars Tests

# %%
import easyocr
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image_path = 'mars4.jpg'
image = cv2.imread(image_path)

reader = easyocr.Reader(['en'])

results = reader.readtext(image)

for (bbox, text, confidence) in results:
    box = [tuple(map(int, point)) for point in bbox]

    cv2.polylines(image, [np.array(box)], isClosed=True, color=(0, 255, 0), thickness=2)

    x, y = box[3]
    text_position = (x, y + 30)
    cv2.putText(image, text, text_position, cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 0, 0), 3)

cv2_imshow(image)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# <PIL.Image.Image image mode=RGB size=193x273>

# %% [markdown]
# # Snickers Tests

# %%
import easyocr
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image_path = 'snickersfull.jpg'
image = cv2.imread(image_path)

reader = easyocr.Reader(['en'])

results = reader.readtext(image)

for (bbox, text, confidence) in results:
    box = [tuple(map(int, point)) for point in bbox]

    cv2.polylines(image, [np.array(box)], isClosed=True, color=(0, 255, 0), thickness=2)

    x, y = box[3]
    text_position = (x, y + 30)
    cv2.putText(image, text, text_position, cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 0, 0), 3)

cv2_imshow(image)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# <PIL.Image.Image image mode=RGB size=345x240>

# %% [markdown]
# # Lion Tests

# %%
import easyocr
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image_path = '/content/lioncrop3.jpg'
image = cv2.imread(image_path)

reader = easyocr.Reader(['en'])

results = reader.readtext(image)

for (bbox, text, confidence) in results:
    box = [tuple(map(int, point)) for point in bbox]

    cv2.polylines(image, [np.array(box)], isClosed=True, color=(0, 255, 0), thickness=2)

    x, y = box[3]
    text_position = (x, y + 30)
    cv2.putText(image, text, text_position, cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 0, 0), 3)

cv2_imshow(image)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# <PIL.Image.Image image mode=RGB size=360x382>

# %% [markdown]
# # PaddleOCR

# %%
# !pip install paddlepaddle paddleocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 76.9 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=3d24782f6b2cdf3f3101cc0cf1a0d6dc5713a4c60aff1e17f914defa6595e197
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...
#   Attempting uninstall: opt_einsum
#     Found existing installation: opt_einsum 3.4.0
# ...

# %% [markdown]
# # Mars Tests

# %%
import cv2
from paddleocr import PaddleOCR
from google.colab.patches import cv2_imshow
import numpy as np

img = cv2.imread('/content/mars4.jpg')

ocr = PaddleOCR(use_angle_cls=True, lang='en')

result = ocr.ocr(img, cls=True)

if result:
    for line in result[0]:
        text = line[1][0]
        coordinates = line[0]

        pts = np.array(coordinates, dtype=np.int32)

        img = cv2.polylines(img, [pts], isClosed=True, color=(0, 255, 0), thickness=2)

        x, y = pts[0][0], pts[0][1]
        cv2.putText(img, text, (x, y + 30), cv2.FONT_HERSHEY_SIMPLEX,
                    1, (255, 0, 0), 2, cv2.LINE_AA)

cv2_imshow(img)
# Out:
# [2025/05/05 22:25:32] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text
# ...

# %% [markdown]
# # Snickers Tests

# %%
import cv2
from paddleocr import PaddleOCR
from google.colab.patches import cv2_imshow
import numpy as np

img = cv2.imread('/content/snickersfull.jpg')

ocr = PaddleOCR(use_angle_cls=True, lang='en')

result = ocr.ocr(img, cls=True)

if result:
    for line in result[0]:
        text = line[1][0]
        coordinates = line[0]
        pts = np.array(coordinates, dtype=np.int32)

        img = cv2.polylines(img, [pts], isClosed=True, color=(0, 255, 0), thickness=2)

        x, y = pts[0][0], pts[0][1]
        cv2.putText(img, text, (x, y + 30), cv2.FONT_HERSHEY_SIMPLEX,
                    1, (255, 0, 0), 2, cv2.LINE_AA)

cv2_imshow(img)
# Out:
# [2025/05/05 22:27:18] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text
# ...

# %%
import cv2
from paddleocr import PaddleOCR
from google.colab.patches import cv2_imshow
import numpy as np

img = cv2.imread('/content/lioncrop3.jpg')

ocr = PaddleOCR(use_angle_cls=True, lang='en')

result = ocr.ocr(img, cls=True)

if result:
    for line in result[0]:
        text = line[1][0]
        coordinates = line[0]
        pts = np.array(coordinates, dtype=np.int32)

        img = cv2.polylines(img, [pts], isClosed=True, color=(0, 255, 0), thickness=2)

        x, y = pts[0][0], pts[0][1]
        cv2.putText(img, text, (x, y + 30), cv2.FONT_HERSHEY_SIMPLEX,
                    1, (255, 0, 0), 2, cv2.LINE_AA)

cv2_imshow(img)
# Out:
# [2025/05/16 13:16:26] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text
# ...
